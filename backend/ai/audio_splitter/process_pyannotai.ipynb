# %%
import json
from pprint import pp

# %%
def string_to_float(time):
    left, right = map(int, time.split(":"))
    assert -1 < right < 60, f"{time} is in invalid format"
    return left + right / 60


def float_to_string(time):
    left = int(time)
    right = int((time - left) * 60)
    return f"{left:02d}:{right:02d}"


print(string_to_float("8:04"))
print(string_to_float("12:3"))
print(float_to_string(8.0666))
print(float_to_string(1234.94321))
# Out:
# 8.066666666666666
# 12.05
# 08:03
# 1234:56

# %%
original_duration = string_to_float("8:04")

with open("output.json") as f:
    data = json.load(f)

# print(data)
print("Conversation fragments count:", len(data["output"]["diarization"]))
print("Confidence scores count:", len(data["output"]["confidence"]["score"]))
print()

total_sex = 0
for i in data["output"]["diarization"]:
    total_sex += i["end"] - i["start"]

print("Conversation duration")
print("\tin seconds:", total_sex)
print("\tin minutes:", total_sex / 60)
print("Original duration")
print("\tin seconds:", original_duration * 60)
print("\tin minutes:", original_duration)
# Out:
# Conversation fragments count: 139
# Confidence scores count: 24224
#
# Conversation duration
# 	in seconds: 273.51999999999975
# 	in minutes: 4.558666666666663
# Original duration
# 	in seconds: 484.0
# 	in minutes: 8.066666666666666

# %%
merged = []

prev_speaker = ""

for i in data["output"]["diarization"]:
    if prev_speaker == i["speaker"]:
        merged[-1]["end"] = i["end"]
    else:
        merged.append(i)
        prev_speaker = i["speaker"]

print("Merged conversation fragments:", len(merged))
pp(merged, indent=2)
# Out:
# Merged conversation fragments: 88
# [ {'speaker': 'SPEAKER_01', 'start': 0.245, 'end': 3.265},
#   {'speaker': 'SPEAKER_00', 'start': 3.425, 'end': 5.705},
#   {'speaker': 'SPEAKER_01', 'start': 6.485, 'end': 7.305},
#   {'speaker': 'SPEAKER_00', 'start': 7.305, 'end': 12.645},
#   {'speaker': 'SPEAKER_01', 'start': 12.645, 'end': 13.965},
#   {'speaker': 'SPEAKER_00', 'start': 13.965, 'end': 17.185},
#   {'speaker': 'SPEAKER_01', 'start': 18.125, 'end': 18.665},
#   {'speaker': 'SPEAKER_00', 'start': 19.385, 'end': 28.025},
#   {'speaker': 'SPEAKER_01', 'start': 30.225, 'end': 32.965},
#   {'speaker': 'SPEAKER_00', 'start': 34.145, 'end': 34.745},
#   {'speaker': 'SPEAKER_01', 'start': 36.665, 'end': 51.465},
#   {'speaker': 'SPEAKER_00', 'start': 51.685, 'end': 60.445},
#   {'speaker': 'SPEAKER_01', 'start': 61.165, 'end': 62.925},
#   {'speaker': 'SPEAKER_00', 'start': 63.705, 'end': 64.865},
#   {'speaker': 'SPEAKER_01', 'start': 65.865, 'end': 66.325},
#   {'speaker': 'SPEAKER_00', 'start': 66.905, 'end': 71.805},
#   {'speaker': 'SPEAKER_01', 'start': 73.125, 'end': 75.185},
#   {'speaker': 'SPEAKER_00', 'start': 76.465, 'end': 81.465},
#   {'speaker': 'SPEAKER_01', 'start': 83.825, 'end': 89.505},
#   {'speaker': 'SPEAKER_00', 'start': 90.445, 'end': 99.505},
#   {'speaker': 'SPEAKER_01', 'start': 99.505, 'end': 99.705},
#   {'speaker': 'SPEAKER_00', 'start': 99.705, 'end': 104.585},
#   {'speaker': 'SPEAKER_01', 'start': 103.805, 'end': 108.145},
#   {'speaker': 'SPEAKER_00', 'start': 109.405, 'end': 111.665},
#   {'speaker': 'SPEAKER_01', 'start': 112.585, 'end': 119.625},
#   {'speaker': 'SPEAKER_00', 'start': 120.105, 'end': 123.185},
#   {'speaker': 'SPEAKER_01', 'start': 124.205, 'end': 128.465},
#   {'speaker': 'SPEAKER_00', 'start': 130.105, 'end': 132.285},
#   {'speaker': 'SPEAKER_01', 'start': 133.045, 'end': 133.765},
#   {'speaker': 'SPEAKER_00', 'start': 134.825, 'end': 136.705},
#   {'speaker': 'SPEAKER_01', 'start': 138.825, 'end': 149.025},
#   {'speaker': 'SPEAKER_00', 'start': 149.305, 'end': 150.505},
#   {'speaker': 'SPEAKER_01', 'start': 151.165, 'end': 152.125},
#   {'speaker': 'SPEAKER_00', 'start': 152.445, 'end': 153.285},
#   {'speaker': 'SPEAKER_01', 'start': 153.185, 'end': 155.545},
#   {'speaker': 'SPEAKER_00', 'start': 156.185, 'end': 167.605},
#   {'speaker': 'SPEAKER_01', 'start': 170.765, 'end': 173.705},
#   {'speaker': 'SPEAKER_00', 'start': 174.105, 'end': 176.825},
#   {'speaker': 'SPEAKER_01', 'start': 180.145, 'end': 182.885},
#   {'speaker': 'SPEAKER_00', 'start': 182.305, 'end': 183.265},
#   {'speaker': 'SPEAKER_01', 'start': 252.065, 'end': 253.525},
#   {'speaker': 'SPEAKER_00', 'start': 253.525, 'end': 254.345},
#   {'speaker': 'SPEAKER_01', 'start': 255.625, 'end': 258.505},
#   {'speaker': 'SPEAKER_00', 'start': 259.005, 'end': 259.565},
#   {'speaker': 'SPEAKER_01', 'start': 260.825, 'end': 264.085},
#   {'speaker': 'SPEAKER_00', 'start': 266.105, 'end': 268.845},
#   {'speaker': 'SPEAKER_01', 'start': 268.845, 'end': 270.025},
#   {'speaker': 'SPEAKER_00', 'start': 270.025, 'end': 270.165},
#   {'speaker': 'SPEAKER_01', 'start': 300.605, 'end': 315.605},
#   {'speaker': 'SPEAKER_00', 'start': 316.605, 'end': 317.765},
#   {'speaker': 'SPEAKER_01', 'start': 316.985, 'end': 318.705},
#   {'speaker': 'SPEAKER_00', 'start': 319.065, 'end': 321.205},
#   {'speaker': 'SPEAKER_01', 'start': 322.025, 'end': 325.565},
#   {'speaker': 'SPEAKER_00', 'start': 325.805, 'end': 326.425},
#   {'speaker': 'SPEAKER_01', 'start': 325.965, 'end': 329.005},
#   {'speaker': 'SPEAKER_00', 'start': 329.845, 'end': 331.045},
#   {'speaker': 'SPEAKER_01', 'start': 331.865, 'end': 335.085},
#   {'speaker': 'SPEAKER_00', 'start': 336.125, 'end': 348.605},
#   {'speaker': 'SPEAKER_01', 'start': 345.385, 'end': 352.985},
#   {'speaker': 'SPEAKER_00', 'start': 353.285, 'end': 357.065},
#   {'speaker': 'SPEAKER_01', 'start': 358.305, 'end': 364.525},
#   {'speaker': 'SPEAKER_00', 'start': 364.665, 'end': 365.525},
#   {'speaker': 'SPEAKER_01', 'start': 391.005, 'end': 392.305},
#   {'speaker': 'SPEAKER_00', 'start': 392.065, 'end': 393.245},
#   {'speaker': 'SPEAKER_01', 'start': 393.865, 'end': 396.145},
#   {'speaker': 'SPEAKER_00', 'start': 396.625, 'end': 405.125},
#   {'speaker': 'SPEAKER_01', 'start': 405.785, 'end': 414.425},
#   {'speaker': 'SPEAKER_00', 'start': 413.505, 'end': 417.425},
#   {'speaker': 'SPEAKER_01', 'start': 419.605, 'end': 420.805},
#   {'speaker': 'SPEAKER_00', 'start': 421.305, 'end': 425.285},
#   {'speaker': 'SPEAKER_01', 'start': 426.445, 'end': 430.025},
#   {'speaker': 'SPEAKER_00', 'start': 431.045, 'end': 433.425},
#   {'speaker': 'SPEAKER_01', 'start': 433.425, 'end': 435.945},
#   {'speaker': 'SPEAKER_00', 'start': 436.845, 'end': 440.885},
#   {'speaker': 'SPEAKER_01', 'start': 440.885, 'end': 441.025},
#   {'speaker': 'SPEAKER_00', 'start': 441.025, 'end': 451.445},
#   {'speaker': 'SPEAKER_01', 'start': 452.325, 'end': 452.885},
#   {'speaker': 'SPEAKER_00', 'start': 453.325, 'end': 456.465},
#   {'speaker': 'SPEAKER_01', 'start': 455.805, 'end': 457.705},
#   {'speaker': 'SPEAKER_00', 'start': 459.225, 'end': 459.465},
#   {'speaker': 'SPEAKER_01', 'start': 459.465, 'end': 460.425},
#   {'speaker': 'SPEAKER_00', 'start': 460.845, 'end': 461.325},
#   {'speaker': 'SPEAKER_01', 'start': 461.265, 'end': 468.005},
#   {'speaker': 'SPEAKER_00', 'start': 468.005, 'end': 468.625},
#   {'speaker': 'SPEAKER_01', 'start': 469.085, 'end': 472.625},
#   {'speaker': 'SPEAKER_00', 'start': 473.445, 'end': 477.965},
#   {'speaker': 'SPEAKER_01', 'start': 477.965, 'end': 480.785},
#   {'speaker': 'SPEAKER_00', 'start': 481.065, 'end': 481.745}]

# %%
import statistics

spans = []

for i in merged:
    spans.append(i["end"] - i["start"])

print("Avg fragment duration:", sum(spans) / len(spans), "seconds")
print("Mean:", statistics.mean(spans))
# Out:
# Avg fragment duration: 3.468636363636361 seconds
# Mean: 3.468636363636361

# %%
from pydub import AudioSegment
from pydub.utils import which

# Set ffmpeg executable path
AudioSegment.converter = which("ffmpeg")

# Load the audio file
audio = AudioSegment.from_file("test.m4a")

timestamps = [(i["start"], i["end"]) for i in merged]

# Loop through timestamps and export each segment
for i, (start, end) in enumerate(timestamps):
    start_ms = start * 1000
    end_ms = end * 1000

    # Extract the audio segment
    segment = audio[start_ms:end_ms]

    # Export the segment as a new file
    output_file = f"output_segment_{i + 1}.mp3"
    segment.export(output_file, format="mp3")
    print(f"Exported {output_file}")
# Out:
# 0 (0.245, 3.265)
# Exported output_segment_1.mp3
# 1 (3.425, 5.705)
# Exported output_segment_2.mp3
# 2 (6.485, 7.305)
# Exported output_segment_3.mp3
# 3 (7.305, 12.645)
# Exported output_segment_4.mp3
# 4 (12.645, 13.965)
# Exported output_segment_5.mp3
# 5 (13.965, 17.185)
# Exported output_segment_6.mp3
# 6 (18.125, 18.665)
# Exported output_segment_7.mp3
# 7 (19.385, 28.025)
# Exported output_segment_8.mp3
# 8 (30.225, 32.965)
# Exported output_segment_9.mp3
# 9 (34.145, 34.745)
# Exported output_segment_10.mp3
# 10 (36.665, 51.465)
# Exported output_segment_11.mp3
# 11 (51.685, 60.445)
# Exported output_segment_12.mp3
# 12 (61.165, 62.925)
# Exported output_segment_13.mp3
# 13 (63.705, 64.865)
# Exported output_segment_14.mp3
# 14 (65.865, 66.325)
# Exported output_segment_15.mp3
# 15 (66.905, 71.805)
# Exported output_segment_16.mp3
# 16 (73.125, 75.185)
# Exported output_segment_17.mp3
# 17 (76.465, 81.465)
# Exported output_segment_18.mp3
# 18 (83.825, 89.505)
# Exported output_segment_19.mp3
# 19 (90.445, 99.505)
# Exported output_segment_20.mp3
# 20 (99.505, 99.705)
# Exported output_segment_21.mp3
# 21 (99.705, 104.585)
# Exported output_segment_22.mp3
# 22 (103.805, 108.145)
# Exported output_segment_23.mp3
# 23 (109.405, 111.665)
# Exported output_segment_24.mp3
# 24 (112.585, 119.625)
# Exported output_segment_25.mp3
# 25 (120.105, 123.185)
# Exported output_segment_26.mp3
# 26 (124.205, 128.465)
# Exported output_segment_27.mp3
# 27 (130.105, 132.285)
# Exported output_segment_28.mp3
# 28 (133.045, 133.765)
# Exported output_segment_29.mp3
# 29 (134.825, 136.705)
# Exported output_segment_30.mp3
# 30 (138.825, 149.025)
# Exported output_segment_31.mp3
# 31 (149.305, 150.505)
# Exported output_segment_32.mp3
# 32 (151.165, 152.125)
# Exported output_segment_33.mp3
# 33 (152.445, 153.285)
# Exported output_segment_34.mp3
# 34 (153.185, 155.545)
# Exported output_segment_35.mp3
# 35 (156.185, 167.605)
# Exported output_segment_36.mp3
# 36 (170.765, 173.705)
# Exported output_segment_37.mp3
# 37 (174.105, 176.825)
# Exported output_segment_38.mp3
# 38 (180.145, 182.885)
# Exported output_segment_39.mp3
# 39 (182.305, 183.265)
# Exported output_segment_40.mp3
# 40 (252.065, 253.525)
# Exported output_segment_41.mp3
# 41 (253.525, 254.345)
# Exported output_segment_42.mp3
# 42 (255.625, 258.505)
# Exported output_segment_43.mp3
# 43 (259.005, 259.565)
# Exported output_segment_44.mp3
# 44 (260.825, 264.085)
# Exported output_segment_45.mp3
# 45 (266.105, 268.845)
# Exported output_segment_46.mp3
# 46 (268.845, 270.025)
# Exported output_segment_47.mp3
# 47 (270.025, 270.165)
# Exported output_segment_48.mp3
# 48 (300.605, 315.605)
# Exported output_segment_49.mp3
# 49 (316.605, 317.765)
# Exported output_segment_50.mp3
# 50 (316.985, 318.705)
# Exported output_segment_51.mp3
# 51 (319.065, 321.205)
# Exported output_segment_52.mp3
# 52 (322.025, 325.565)
# Exported output_segment_53.mp3
# 53 (325.805, 326.425)
# Exported output_segment_54.mp3
# 54 (325.965, 329.005)
# Exported output_segment_55.mp3
# 55 (329.845, 331.045)
# Exported output_segment_56.mp3
# 56 (331.865, 335.085)
# Exported output_segment_57.mp3
# 57 (336.125, 348.605)
# Exported output_segment_58.mp3
# 58 (345.385, 352.985)
# Exported output_segment_59.mp3
# 59 (353.285, 357.065)
# Exported output_segment_60.mp3
# 60 (358.305, 364.525)
# Exported output_segment_61.mp3
# 61 (364.665, 365.525)
# Exported output_segment_62.mp3
# 62 (391.005, 392.305)
# Exported output_segment_63.mp3
# 63 (392.065, 393.245)
# Exported output_segment_64.mp3
# 64 (393.865, 396.145)
# Exported output_segment_65.mp3
# 65 (396.625, 405.125)
# Exported output_segment_66.mp3
# 66 (405.785, 414.425)
# Exported output_segment_67.mp3
# 67 (413.505, 417.425)
# Exported output_segment_68.mp3
# 68 (419.605, 420.805)
# Exported output_segment_69.mp3
# 69 (421.305, 425.285)
# Exported output_segment_70.mp3
# 70 (426.445, 430.025)
# Exported output_segment_71.mp3
# 71 (431.045, 433.425)
# Exported output_segment_72.mp3
# 72 (433.425, 435.945)
# Exported output_segment_73.mp3
# 73 (436.845, 440.885)
# Exported output_segment_74.mp3
# 74 (440.885, 441.025)
# Exported output_segment_75.mp3
# 75 (441.025, 451.445)
# Exported output_segment_76.mp3
# 76 (452.325, 452.885)
# Exported output_segment_77.mp3
# 77 (453.325, 456.465)
# Exported output_segment_78.mp3
# 78 (455.805, 457.705)
# Exported output_segment_79.mp3
# 79 (459.225, 459.465)
# Exported output_segment_80.mp3
# 80 (459.465, 460.425)
# Exported output_segment_81.mp3
# 81 (460.845, 461.325)
# Exported output_segment_82.mp3
# 82 (461.265, 468.005)
# Exported output_segment_83.mp3
# 83 (468.005, 468.625)
# Exported output_segment_84.mp3
# 84 (469.085, 472.625)
# Exported output_segment_85.mp3
# 85 (473.445, 477.965)
# Exported output_segment_86.mp3
# 86 (477.965, 480.785)
# Exported output_segment_87.mp3
# 87 (481.065, 481.745)
# Exported output_segment_88.mp3
